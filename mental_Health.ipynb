# %% [markdown]
# # tweets in a one file with count in Array

# %%
import tweepy 
import csv
import io

#Twitter API credentials

consumer_key = 'd7RJDeV6M1TdKnXXdY29Zud5O'
consumer_secret = '8LV35luiAco2mBnQ1W6erOnA8cbMwVgxblfHjP5zk5dmAXGwd6'
access_key = '2206645458-9qlftwQ5eiovob7GCp21VrAoFRXi7AJLGt5ts3O'
access_secret = 'Oc9ZKbHSL0reJhZYcU0Vk9UERbVvsTwerIfDUTwiRNGYf'

#with io.open(f'tweetsAll.csv', "a", encoding="utf-8") as f:

All_Users_tweets=[]
All_Tweetscount_forindividual_user=[]
def get_all_tweets(screen_name):
    #Twitter only allows access to a users most recent 3240 tweets with this method
    
    #authorize twitter, initialize tweepy
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_key, access_secret)
    api = tweepy.API(auth)
    
    #initialize a list to hold all the tweepy Tweets
    alltweets = []  
    
    #make initial request for most recent tweets (200 is the maximum allowed count)
    new_tweets = api.user_timeline(screen_name = screen_name,count=200)
    
    #save most recent tweets
    alltweets.extend(new_tweets)
    
    #save the id of the oldest tweet less one
    oldest = alltweets[-1].id - 1
    
    #keep grabbing tweets until there are no tweets left to grab
    while len(new_tweets) > 0:
        print(f"getting tweets before {oldest}")
        count=0
        #alltweets=[]
        #alltweets.append(screen_name)
        
        #all subsiquent requests use the max_id param to prevent duplicates
        new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest)
        
        #save most recent tweets
        alltweets.extend(new_tweets)
        
        #update the id of the oldest tweet less one
        oldest = alltweets[-1].id - 1
        
        print(f"...{len(alltweets)} tweets downloaded so far")
        #print(alltweets)
        count=count+len(alltweets)
    
    #transform the tweepy tweets into a 2D array that will populate the csv 
    outtweets = [[tweet.id_str,tweet.text] for tweet in alltweets]
    All_Users_tweets.extend(outtweets)
    All_Tweetscount_forindividual_user.append(count)

    
    pass
    

#write the csv  
#with io.open(f'AllFinaltweetswithcount.csv', "a", encoding="utf-8") as f:
    #with open(f'new_{screen_name}_tweets.csv', 'w') as f:
    #writer = csv.writer(f)
    #writer.writerow(["id","text"])
    #writer.writerows(All_Users_tweets)
    
    
    
    
name=["J_tsar",'Daniel78037553','VenglishWell','ida_skibenes','GraceYeohCNA']
for i in range(len(name)):
    if __name__ == '__main__':
    #pass in the username of the account you want to download
        get_all_tweets(name[i])
# Out:
# getting tweets before 292903444233207809
# ...386 tweets downloaded so far
# getting tweets before 265207522573574143
# ...574 tweets downloaded so far
# getting tweets before 223267302274105343
# ...752 tweets downloaded so far
# getting tweets before 199801567199760383
# ...943 tweets downloaded so far
# getting tweets before 175125043918028799
# ...968 tweets downloaded so far
# getting tweets before 128727410161102847
# ...968 tweets downloaded so far
# getting tweets before 1399685061671223298
# ...400 tweets downloaded so far
# getting tweets before 1399363389663580160
# ...600 tweets downloaded so far
# getting tweets before 1399023987150114817
# ...800 tweets downloaded so far
# getting tweets before 1398619486555500546
# ...1000 tweets downloaded so far
# getting tweets before 1398226311324200971
# ...1200 tweets downloaded so far
# getting tweets before 1397898832969568262
# ...1400 tweets downloaded so far
# getting tweets before 1397549172056739841
# ...1600 tweets downloaded so far
# getting tweets before 1397089595817226239
# ...1800 tweets downloaded so far
# getting tweets before 1396508792112615432
# ...2000 tweets downloaded so far
# getting tweets before 1395963457996943360
# ...2200 tweets downloaded so far
# getting tweets before 1395207815220715519
# ...2399 tweets downloaded so far
# getting tweets before 1394121873999335423
# ...2597 tweets downloaded so far
# getting tweets before 1393460870605271039
# ...2791 tweets downloaded so far
# getting tweets before 1393038237350825984
# ...2986 tweets downloaded so far
# getting tweets before 1392504817784803328
# ...3183 tweets downloaded so far
# getting tweets before 1392051916272717823
# ...3231 tweets downloaded so far
# getting tweets before 1391970603129720835
# ...3231 tweets downloaded so far
# getting tweets before 1390355033376665599
# ...400 tweets downloaded so far
# getting tweets before 1381497498951368709
# ...600 tweets downloaded so far
# getting tweets before 1368822439430533120
# ...800 tweets downloaded so far
# getting tweets before 1357986268098027520
# ...1000 tweets downloaded so far
# getting tweets before 1348221800837242880
# ...1200 tweets downloaded so far
# getting tweets before 1333334113684770815
# ...1400 tweets downloaded so far
# getting tweets before 1321331414101565439
# ...1599 tweets downloaded so far
# getting tweets before 1303958801343709183
# ...1799 tweets downloaded so far
# getting tweets before 1293080752763154432
# ...1999 tweets downloaded so far
# getting tweets before 1284767619480981503
# ...2198 tweets downloaded so far
# getting tweets before 1280741359079567360
# ...2398 tweets downloaded so far
# getting tweets before 1273512682860265471
# ...2598 tweets downloaded so far
# getting tweets before 1268503829651341311
# ...2798 tweets downloaded so far
# getting tweets before 1263764196442943487
# ...2997 tweets downloaded so far
# getting tweets before 1258988311978414080
# ...3196 tweets downloaded so far
# getting tweets before 1253387845550694399
# ...3246 tweets downloaded so far
# getting tweets before 1252835532163280897
# ...3246 tweets downloaded so far
# getting tweets before 1395506708626255871
# ...398 tweets downloaded so far
# getting tweets before 1391522748279795718
# ...596 tweets downloaded so far
# getting tweets before 1386327146910584834
# ...794 tweets downloaded so far
# getting tweets before 1380617249552224255
# ...994 tweets downloaded so far
# getting tweets before 1379103296179347456
# ...1194 tweets downloaded so far
# getting tweets before 1377030174739460101
# ...1394 tweets downloaded so far
# getting tweets before 1372835680271892480
# ...1594 tweets downloaded so far
# getting tweets before 1369738935258210305
# ...1792 tweets downloaded so far
# getting tweets before 1366803217074577408
# ...1992 tweets downloaded so far
# getting tweets before 1366023698873012226
# ...2192 tweets downloaded so far
# getting tweets before 1365804199519412225
# ...2392 tweets downloaded so far
# getting tweets before 1364612121137459202
# ...2592 tweets downloaded so far
# getting tweets before 1362843770883084289
# ...2792 tweets downloaded so far
# getting tweets before 1360041797729271810
# ...2992 tweets downloaded so far
# getting tweets before 1358234603442552831
# ...3191 tweets downloaded so far
# getting tweets before 1356006184134782976
# ...3241 tweets downloaded so far
# getting tweets before 1355492376056356870
# ...3241 tweets downloaded so far
# getting tweets before 1387376880232189960
# ...62 tweets downloaded so far

# %%
# array with count of tweets

# %%
print("Array with count of tweets posted by them:",All_Tweetscount_forindividual_user)
# Out:
# Array with count of tweets posted by them: [968, 3231, 3246, 3241, 62]

# %%
# writing tweets of all user in one single file

# %%
with io.open(f'finalfile.csv', "a", encoding="utf-8") as f:
    #with open(f'new_{screen_name}_tweets.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerow(["id","text"])
    writer.writerows(All_Users_tweets)

# %%
# reading file

# %%
import pandas as pd

# %%
file=pd.read_csv(r"finalfile.csv")

# %%
file.head(5)
# Out:
#                    id                                               text
# 0  324583813902655489  RT @muftimenk: Attitude can take away your bea...
# 1  324397718099353601                      I'm a stress free kind of guy
# 2  324348831938519040  Nowadays everybody wanna talk like they got so...
# 3  324268440082841600                              @ImRealTed fake story
# 4  324211255869067266  So then I says to him, I says, relax bro my be...

# %%
file.shape
# Out:
# (10748, 2)

# %%
file.columns
# Out:
# Index(['id', 'text'], dtype='object')

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sent=SentimentIntensityAnalyzer()
l1=[]
for j in file['text']:
    abc=sent.polarity_scores(j)
    if(abc['compound']>0):
        l1.append(1)
    elif(abc['compound']<0):
        l1.append(-1)
    else:
        l1.append(0)

# %%
file['Polarity']=l1

# %%
file.head(5)
# Out:
#                    id                                               text  \
# 0  324583813902655489  RT @muftimenk: Attitude can take away your bea...
# 1  324397718099353601                      I'm a stress free kind of guy
# 2  324348831938519040  Nowadays everybody wanna talk like they got so...
# 3  324268440082841600                              @ImRealTed fake story
# 4  324211255869067266  So then I says to him, I says, relax bro my be...
#
#    Polarity
# 0         1
# 1         1
# 2         1
# 3        -1
# 4         1

# %%
name=["J_tsar",'Daniel78037553','VenglishWell','ida_skibenes','GraceYeohCNA']
#All_Tweetscount_forindividual_user=[968, 3231, 3246, 3241, 62] we get throght code

# %%
l2=[]
for i in range(len(All_Tweetscount_forindividual_user)):
    for j in range(All_Tweetscount_forindividual_user[i]):
        l2.append(name[i])

# %%
l2
# Out:
# ['J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'J_tsar',
#  'Daniel78037553',
#  'Daniel78037553',
#  'Daniel78037553',
#  'Daniel78037553',
#  'Daniel78037553',
#  'Daniel78037553',
#  'Daniel78037553',
#  'Daniel78037553',
#  'Daniel78037553',
#  'Daniel78037553',
#  'Daniel78037553',
#  'Daniel78037553',
#  'Daniel78037553',
#  'Daniel78037553',
#  'Daniel78037553',
#  'Daniel78037553',
#  'Daniel78037553',
#  'Daniel78037553',
#  'Daniel78037553',
#  'Daniel78037553',
#  'Daniel78037553',
#  'Daniel78037553',
#  'Daniel78037553',
#  'Daniel78037553',
#  'Daniel78037553',
#  'Daniel78037553',
#  'Daniel78037553',
#  'Daniel78037553',
#  'Daniel78037553',
#  'Daniel78037553',
#  'Daniel78037553',
#  'Daniel78037553',
#  ...]

# %%
file['person']=l2

# %%
file.head(10)
# Out:
#                    id                                               text  \
# 0  324583813902655489  RT @muftimenk: Attitude can take away your bea...
# 1  324397718099353601                      I'm a stress free kind of guy
# 2  324348831938519040  Nowadays everybody wanna talk like they got so...
# 3  324268440082841600                              @ImRealTed fake story
# 4  324211255869067266  So then I says to him, I says, relax bro my be...
# 5  324210172862025729  @therealAbdul_ #heavy I've been looking for th...
# 6  324209310936752129      @therealAbdul_ you need to get Claritin clear
# 7  324017963587993600  There are people that know the truth but stay ...
# 8  323998162249474048                                   @mellochamp *say
# 9  323997583372599297  @MelloChamp and they what "god hates dead peop...
#
#    Polarity  person
# 0         1  J_tsar
# 1         1  J_tsar
# 2         1  J_tsar
# 3        -1  J_tsar
# 4         1  J_tsar
# 5        -1  J_tsar
# 6         1  J_tsar
# 7         1  J_tsar
# 8         0  J_tsar
# 9        -1  J_tsar
